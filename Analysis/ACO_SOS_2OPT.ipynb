# %%
import sys
import os
import subprocess
from tqdm import tqdm

# %%
os.system('g++  aco_sos_2OPT.cpp')
# Out:
# 0

# %%
dataset = ['eil51.txt','eil76.txt','kroA100.txt','ch150.txt','kroA200.txt']
num_iterations = [50,100,150,200,250,300]
bks =  [426,538,21282,6528,29368]
best = [[None for i in range(6)] for i in range(5)]
avg = [[None for i in range(6)] for i in range(5)]
error = [[None for i in range(6)] for i in range(5)]
for k in range(len(dataset)):
  filename = dataset[k]
  print("filename: ",filename)
  for j in range(len(num_iterations)):
    num_itr = num_iterations[j]
    distances = []
    print("Num of Iteration: ",num_itr)
    for i in range(5):
      processInfo = ['./a.out', filename,str(num_itr)]
      backend   = subprocess.Popen(processInfo, stdout=subprocess.PIPE)
      dataBytes = backend.communicate()[0]
      dataStr   = dataBytes.decode('utf-8')
      distances.append(float(dataStr))
    best[k][j] = min(distances)
    avg[k][j] = sum(distances)/len(distances)
    error[k][j] = ((avg[k][j]-bks[k])/bks[k])*100
    print("best: ", best[k][j])
    print("average: ",avg[k][j])
    print("error: ",error[k][j])
    print("\n")
# Out:
# filename:  eil51.txt
# Num of Iteration:  50
# best:  435.152
# average:  441.3218
# error:  3.5966666666666662
#
#
# Num of Iteration:  100
# best:  429.983
# average:  437.1988
# error:  2.6288262910798132
#
#
# Num of Iteration:  150
# best:  434.91
# average:  439.7536
# error:  3.2285446009389687
#
#
# Num of Iteration:  200
# best:  435.666
# average:  437.0494
# error:  2.5937558685445987
#
#
# Num of Iteration:  250
# best:  433.199
# average:  435.34
# error:  2.1924882629107922
#
#
# Num of Iteration:  300
# best:  435.465
# average:  436.48019999999997
# error:  2.460140845070415
#
#
# filename:  eil76.txt
# Num of Iteration:  50
# best:  559.834
# average:  565.4588
# error:  5.103866171003717
#
#
# Num of Iteration:  100
# best:  559.295
# average:  561.8858
# error:  4.439739776951676
#
#
# Num of Iteration:  150
# best:  554.642
# average:  561.1586
# error:  4.304572490706315
#
#
# Num of Iteration:  200
# best:  554.592
# average:  556.7214
# error:  3.4798141263940554
#
#
# Num of Iteration:  250
# best:  558.333
# average:  561.0688
# error:  4.287881040892196
#
#
# Num of Iteration:  300
# best:  552.709
# average:  558.0812
# error:  3.7325650557620755
#
#
# filename:  kroA100.txt
# Num of Iteration:  50
# best:  22386.2
# average:  22711.239999999998
# error:  6.715722206559524
#
#
# Num of Iteration:  100
# best:  22258.4
# average:  22482.04
# error:  5.638755756037971
#
#
# Num of Iteration:  150
# best:  21958.3
# average:  22181.34
# error:  4.225824640541303
#
#
# Num of Iteration:  200
# best:  21857.5
# average:  22091.6
# error:  3.804153744948776
#
#
# Num of Iteration:  250
# best:  21671.9
# average:  21865.500000000004
# error:  2.741753594586992
#
#
# Num of Iteration:  300
# best:  21708.2
# average:  22007.3
# error:  3.4080443567333862
#
#
# filename:  ch150.txt
# Num of Iteration:  50
# best:  6683.73
# average:  6724.814
# error:  3.0149203431372595
#
#
# Num of Iteration:  100
# best:  6688.82
# average:  6724.129999999999
# error:  3.0044424019607723
#
#
# Num of Iteration:  150
# best:  6626.84
# average:  6662.339999999999
# error:  2.057904411764694
#
#
# Num of Iteration:  200
# best:  6632.14
# average:  6659.5340000000015
# error:  2.0149203431372777
#
#
# Num of Iteration:  250
# best:  6610.88
# average:  6637.794
# error:  1.6818933823529392
#
#
# Num of Iteration:  300
# best:  6584.32
# average:  6607.933999999999
# error:  1.2244791666666557
#
#
# filename:  kroA200.txt
# Num of Iteration:  50
# best:  31527.9
# average:  31822.02
# error:  8.356101879596842
#
#
# Num of Iteration:  100
# best:  31229.4
# average:  31653.059999999998
# error:  7.780781803323338
#
#
# Num of Iteration:  150
# best:  30882.8
# average:  31461.9
# error:  7.129869245437217
#
#
# Num of Iteration:  200
# best:  30988.8
# average:  31259.0
# error:  6.438981204031599
#
#
# Num of Iteration:  250
# best:  30298.6
# average:  30783.6
# error:  4.820212476164528
#
#
# Num of Iteration:  300
# best:  30568.4
# average:  30838.640000000003
# error:  5.007627349496061
