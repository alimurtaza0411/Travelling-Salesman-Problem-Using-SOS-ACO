# %%
import sys
import os
import subprocess
from tqdm import tqdm

# %%
os.system('g++  aco_sos_RR.cpp')
# Out:
# 0

# %%
dataset = ['eil51.txt','eil76.txt','kroA100.txt','ch150.txt','kroA200.txt']
num_iterations = [50,100,150,200,250,300]
bks =  [426,538,21282,6528,29368]
best = [[None for i in range(6)] for i in range(5)]
avg = [[None for i in range(6)] for i in range(5)]
error = [[None for i in range(6)] for i in range(5)]
for k in range(len(dataset)):
  filename = dataset[k]
  print("filename: ",filename)
  for j in range(len(num_iterations)):
    num_itr = num_iterations[j]
    distances = []
    print("Num of Iteration: ",num_itr)
    for i in range(5):
      processInfo = ['./a.out', filename,str(num_itr)]
      backend   = subprocess.Popen(processInfo, stdout=subprocess.PIPE)
      dataBytes = backend.communicate()[0]
      dataStr   = dataBytes.decode('utf-8')
      distances.append(float(dataStr))
    best[k][j] = min(distances)
    avg[k][j] = sum(distances)/len(distances)
    error[k][j] = ((avg[k][j]-bks[k])/bks[k])*100
    print("best: ", best[k][j])
    print("average: ",avg[k][j])
    print("error: ",error[k][j])
    print("\n")
# Out:
# filename:  eil51.txt
# Num of Iteration:  50
# best:  449.239
# average:  451.8328
# error:  6.064037558685451
#
#
# Num of Iteration:  100
# best:  448.21
# average:  451.68379999999996
# error:  6.029061032863841
#
#
# Num of Iteration:  150
# best:  443.489
# average:  447.88
# error:  5.136150234741783
#
#
# Num of Iteration:  200
# best:  444.039
# average:  449.421
# error:  5.49788732394366
#
#
# Num of Iteration:  250
# best:  446.532
# average:  451.1192
# error:  5.896525821596239
#
#
# Num of Iteration:  300
# best:  445.633
# average:  451.8008
# error:  6.05652582159624
#
#
# filename:  eil76.txt
# Num of Iteration:  50
# best:  566.01
# average:  569.9998
# error:  5.9479182156133925
#
#
# Num of Iteration:  100
# best:  560.724
# average:  566.3138000000001
# error:  5.262788104089243
#
#
# Num of Iteration:  150
# best:  556.656
# average:  562.5196
# error:  4.5575464684014815
#
#
# Num of Iteration:  200
# best:  558.58
# average:  561.9008
# error:  4.442527881040893
#
#
# Num of Iteration:  250
# best:  558.58
# average:  564.6376
# error:  4.951226765799261
#
#
# Num of Iteration:  300
# best:  556.656
# average:  564.0236
# error:  4.837100371747209
#
#
# filename:  kroA100.txt
# Num of Iteration:  50
# best:  22968.3
# average:  23308.42
# error:  9.521755474109568
#
#
# Num of Iteration:  100
# best:  22300.9
# average:  22887.839999999997
# error:  7.54553143501549
#
#
# Num of Iteration:  150
# best:  22353.4
# average:  22787.28
# error:  7.073019453058918
#
#
# Num of Iteration:  200
# best:  22428.5
# average:  22692.079999999998
# error:  6.625693073959206
#
#
# Num of Iteration:  250
# best:  22407.7
# average:  22659.159999999996
# error:  6.471008363875558
#
#
# Num of Iteration:  300
# best:  22335.6
# average:  22682.8
# error:  6.582088149609995
#
#
# filename:  ch150.txt
# Num of Iteration:  50
# best:  6736.22
# average:  6788.332
# error:  3.9879289215686327
#
#
# Num of Iteration:  100
# best:  6700.08
# average:  6741.244000000001
# error:  3.2666053921568716
#
#
# Num of Iteration:  150
# best:  6664.07
# average:  6722.094
# error:  2.973253676470589
#
#
# Num of Iteration:  200
# best:  6660.48
# average:  6705.284
# error:  2.7157475490196026
#
#
# Num of Iteration:  250
# best:  6640.57
# average:  6691.312
# error:  2.5017156862745082
#
#
# Num of Iteration:  300
# best:  6652.76
# average:  6675.234000000001
# error:  2.2554227941176666
#
#
# filename:  kroA200.txt
# Num of Iteration:  50
# best:  31882.1
# average:  32049.7
# error:  9.131367474802508
#
#
# Num of Iteration:  100
