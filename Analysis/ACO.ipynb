# %%
import sys
import os
import subprocess
from tqdm import tqdm

# %%
os.system('g++ -I ./ aco.cpp')
# Out:
# 0

# %%
dataset = ['eil51.txt','eil76.txt','kroA100.txt','ch150.txt','kroA200.txt']
num_iterations = [50,100,150,200,250,300]
bks =  [426,538,21282,6528,29368]
best = [[None for i in range(6)] for i in range(5)]
avg = [[None for i in range(6)] for i in range(5)]
error = [[None for i in range(6)] for i in range(5)]
for k in range(len(dataset)):
  filename = dataset[k]
  print("filename: ",filename)
  for j in range(len(num_iterations)):
    num_itr = num_iterations[j]
    distances = []
    print("Num of Iteration: ",num_itr)
    for i in range(5):
      processInfo = ['./a.out', filename,str(num_itr)]
      backend   = subprocess.Popen(processInfo, stdout=subprocess.PIPE)
      dataBytes = backend.communicate()[0]
      dataStr   = dataBytes.decode('utf-8')
      distances.append(float(dataStr))
    best[k][j] = min(distances)
    avg[k][j] = sum(distances)/len(distances)
    error[k][j] = ((avg[k][j]-bks[k])/bks[k])*100
    print("best: ", best[k][j])
    print("average: ",avg[k][j])
    print("error: ",error[k][j])
    print("\n")
# Out:
# filename:  eil51.txt
# Num of Iteration:  50
# best:  458.05
# average:  465.4192
# error:  9.253333333333332
#
#
# Num of Iteration:  100
# best:  450.969
# average:  457.879
# error:  7.483333333333338
#
#
# Num of Iteration:  150
# best:  452.705
# average:  456.8272
# error:  7.2364319248826305
#
#
# Num of Iteration:  200
# best:  444.704
# average:  454.0282
# error:  6.5793896713615085
#
#
# Num of Iteration:  250
# best:  448.039
# average:  453.692
# error:  6.500469483568076
#
#
# Num of Iteration:  300
# best:  450.552
# average:  457.087
# error:  7.2974178403755845
#
#
# filename:  eil76.txt
# Num of Iteration:  50
# best:  556.656
# average:  575.8969999999999
# error:  7.044052044609653
#
#
# Num of Iteration:  100
# best:  556.656
# average:  578.1951999999999
# error:  7.471226765799235
#
#
# Num of Iteration:  150
# best:  566.748
# average:  580.5852
# error:  7.915464684014867
#
#
# Num of Iteration:  200
# best:  564.38
# average:  573.0564
# error:  6.516059479553913
#
#
# Num of Iteration:  250
# best:  575.178
# average:  582.3896
# error:  8.250855018587355
#
#
# Num of Iteration:  300
# best:  571.579
# average:  577.3174
# error:  7.308066914498144
#
#
# filename:  kroA100.txt
# Num of Iteration:  50
# best:  23005.9
# average:  23639.04
# error:  11.075274880180439
#
#
# Num of Iteration:  100
# best:  22803.5
# average:  23460.7
# error:  10.237289728408989
#
#
# Num of Iteration:  150
# best:  23153.7
# average:  23373.64
# error:  9.828211634244898
#
#
# Num of Iteration:  200
# best:  22540.2
# average:  22879.54
# error:  7.50653134103938
#
#
# Num of Iteration:  250
# best:  22546.8
# average:  23008.54
# error:  8.112677379945497
#
#
# Num of Iteration:  300
# best:  22855.8
# average:  23125.18
# error:  8.6607461704727
#
#
# filename:  ch150.txt
# Num of Iteration:  50
# best:  6844.93
# average:  6944.378
# error:  6.378339460784309
#
#
# Num of Iteration:  100
# best:  6724.36
# average:  6873.5160000000005
# error:  5.292830882352949
#
#
# Num of Iteration:  150
# best:  6746.42
# average:  6804.93
# error:  4.242187500000004
#
#
# Num of Iteration:  200
# best:  6734.42
# average:  6794.005999999999
# error:  4.074846813725481
#
#
# Num of Iteration:  250
# best:  6691.77
# average:  6773.581999999999
# error:  3.7619791666666575
#
#
# Num of Iteration:  300
# best:  6744.13
# average:  6879.610000000001
# error:  5.386182598039225
#
#
# filename:  kroA200.txt
# Num of Iteration:  50
# best:  32800.4
# average:  34036.1
# error:  15.895192045764093
#
#
# Num of Iteration:  100
# best:  31678.6
# average:  33106.64
# error:  12.730318714246797
#
#
# Num of Iteration:  150
# best:  32345.9
# average:  33105.03999999999
# error:  12.724870607463885
#
#
# Num of Iteration:  200
# best:  31787.1
# average:  32736.9
# error:  11.47132933805503
#
#
# Num of Iteration:  250
# best:  32918.6
# average:  33323.42
# error:  13.468469081994
#
#
# Num of Iteration:  300
# best:  31293.2
# average:  32443.760000000002
# error:  10.473168074094259
