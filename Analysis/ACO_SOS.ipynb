# %%
import sys
import os
import subprocess
from tqdm import tqdm

# %%
os.system('g++ -I ./ aco_sos.cpp')
# Out:
# 0

# %%
dataset = ['eil51.txt','eil76.txt','kroA100.txt','ch150.txt','kroA200.txt']
num_iterations = [50,100,150,200,250,300]
bks =  [426,538,21282,6528,29368]
best = [[None for i in range(6)] for i in range(5)]
avg = [[None for i in range(6)] for i in range(5)]
error = [[None for i in range(6)] for i in range(5)]
for k in range(len(dataset)):
  filename = dataset[k]
  print("filename: ",filename)
  for j in range(len(num_iterations)):
    num_itr = num_iterations[j]
    distances = []
    print("Num of Iteration: ",num_itr)
    for i in range(5):
      processInfo = ['./a.out', filename,str(num_itr)]
      backend   = subprocess.Popen(processInfo, stdout=subprocess.PIPE)
      dataBytes = backend.communicate()[0]
      dataStr   = dataBytes.decode('utf-8')
      distances.append(float(dataStr))
    best[k][j] = min(distances)
    avg[k][j] = sum(distances)/len(distances)
    error[k][j] = ((avg[k][j]-bks[k])/bks[k])*100
    print("best: ", best[k][j])
    print("average: ",avg[k][j])
    print("error: ",error[k][j])
    print("\n")
# Out:
# filename:  eil51.txt
# Num of Iteration:  50
# best:  448.919
# average:  453.7254000000001
# error:  6.508309859154951
#
#
# Num of Iteration:  100
# best:  446.229
# average:  452.19659999999993
# error:  6.149436619718294
#
#
# Num of Iteration:  150
# best:  448.21
# average:  453.038
# error:  6.346948356807515
#
#
# Num of Iteration:  200
# best:  437.285
# average:  446.02520000000004
# error:  4.700751173708929
#
#
# Num of Iteration:  250
# best:  441.94
# average:  446.9666
# error:  4.921737089201884
#
#
# Num of Iteration:  300
# best:  441.337
# average:  446.15599999999995
# error:  4.731455399061021
#
#
# filename:  eil76.txt
# Num of Iteration:  50
# best:  565.406
# average:  572.9014
# error:  6.4872490706319645
#
#
# Num of Iteration:  100
# best:  564.224
# average:  569.5246
# error:  5.859591078066908
#
#
# Num of Iteration:  150
# best:  566.01
# average:  570.6846
# error:  6.075204460966551
#
#
# Num of Iteration:  200
# best:  556.656
# average:  560.6812000000001
# error:  4.215836431226784
#
#
# Num of Iteration:  250
# best:  565.028
# average:  567.9586
# error:  5.568513011152425
#
#
# Num of Iteration:  300
# best:  556.656
# average:  558.2798
# error:  3.7694795539033503
#
#
# filename:  kroA100.txt
# Num of Iteration:  50
# best:  22852.5
# average:  23061.32
# error:  8.360680387181654
#
#
# Num of Iteration:  100
# best:  22644.4
# average:  22893.3
# error:  7.571186918522692
#
#
# Num of Iteration:  150
# best:  22486.9
# average:  22759.02
# error:  6.940231181279957
#
#
# Num of Iteration:  200
# best:  22591.1
# average:  22675.86
# error:  6.549478432478153
#
#
# Num of Iteration:  250
# best:  22125.8
# average:  22489.239999999998
# error:  5.672587162860624
#
#
# Num of Iteration:  300
# best:  22225.8
# average:  22525.86
# error:  5.844657457005923
#
#
# filename:  ch150.txt
# Num of Iteration:  50
# best:  6723.09
# average:  6771.295999999999
# error:  3.7269607843137162
#
#
# Num of Iteration:  100
# best:  6691.16
# average:  6753.223999999999
# error:  3.4501225490195964
#
#
# Num of Iteration:  150
# best:  6700.78
# average:  6749.312
# error:  3.390196078431371
#
#
# Num of Iteration:  200
# best:  6700.08
# average:  6728.38
# error:  3.0695465686274526
#
#
# Num of Iteration:  250
# best:  6709.52
# average:  6754.201999999999
# error:  3.465104166666656
#
#
# Num of Iteration:  300
# best:  6708.78
# average:  6738.992
# error:  3.232107843137258
#
#
# filename:  kroA200.txt
# Num of Iteration:  50
# best:  31980.3
# average:  32164.839999999997
# error:  9.523426859166428
#
#
# Num of Iteration:  100
# best:  31535.9
# average:  31952.359999999997
# error:  8.799918278398247
#
#
# Num of Iteration:  150
# best:  31360.3
# average:  31974.940000000002
# error:  8.876804685371841
#
#
# Num of Iteration:  200
# best:  31082.0
# average:  31614.02
# error:  7.647847997820759
#
#
# Num of Iteration:  250
# best:  31387.1
# average:  31553.620000000003
# error:  7.442181966766557
#
#
# Num of Iteration:  300
# best:  31151.2
# average:  31517.22
# error:  7.318237537455738
